# %%
# %sql
create catalog demo
managed location 'abfss://demo@deacourseextdlmarek.dfs.core.windows.net/';

create schema if not exists demo.delta_lake
managed location 'abfss://demo@deacourseextdlmarek.dfs.core.windows.net/delta_lake';

# %%
# %sql

create  table if not exists demo.delta_lake.companies
(company_name STRING,
founded_date DATE,
country STRING);

# %%
# %sql

desc extended demo.delta_lake.companies

# %%
# %sql

INSERT INTO demo.delta_lake.companies VALUES ('Microsoft', '1975-04-04', 'USA');

# %%
# %sql
INSERT INTO demo.delta_lake.companies VALUES ('Google', '1998-09-04', 'USA');

# %%
# %sql

DESCRIBE HISTORY demo.delta_lake.companies
