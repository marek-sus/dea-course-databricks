-- %%
CREATE EXTERNAL LOCATION dea_course_ext_dl_circuitbox
URL 'abfss://curcuitbox@deacourseextdlmarek.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL dea-course-ext-sc)

-- %%
CREATE CATALOG circuitbox
MANAGED LOCATION 'abfss://curcuitbox@deacourseextdlmarek.dfs.core.windows.net/'

-- %%
SHOW CATALOGS

-- %%
use catalog circuitbox;

create schema landing
managed location 'abfss://curcuitbox@deacourseextdlmarek.dfs.core.windows.net/landing';

create schema lakehouse
managed location 'abfss://curcuitbox@deacourseextdlmarek.dfs.core.windows.net/lakehouse';

-- %%
show schemas

-- %%
use catalog circuitbox;
use schema landing;

create external volume operational_data
location 'abfss://curcuitbox@deacourseextdlmarek.dfs.core.windows.net/landing/operational_data';

-- %%
%fs ls /Volumes/circuitbox/landing/operational_data
